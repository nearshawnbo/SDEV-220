# %%
#3.1
seconds_per_min = 60
min_per_hour = 60
#3.2
seconds_per_hour = min_per_hour * seconds_per_min
print(seconds_per_hour)
# Out:
# 3600

# %% [markdown]
# #3.1 There are 3600 seconds in one hour.

# %%
#3.3
print(seconds_per_hour * 24)
# Out:
# 86400

# %% [markdown]
# #3.3 There are 86400 seconds in one day.

# %%
#3.4
seconds_per_day = seconds_per_hour * 24
#3.5
print(seconds_per_day / seconds_per_hour)
#3.6
print(seconds_per_day // seconds_per_hour)
# Out:
# 24.0
# 24

# %% [markdown]
# #3.6 Yes.
